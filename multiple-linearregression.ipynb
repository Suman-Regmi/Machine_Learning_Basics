# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from matplotlib import pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        filenames = os.path.join(dirname, filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 import numpy as np # linear algebra
#       6 import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# ----> 7 import seaborn as sns
#       8 from matplotlib import pyplot as plt
#       9 # Input data files are available in the read-only "../input/" directory
#      10 # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
print(filenames)
# Out:
# /kaggle/input/medical-insurance-cost-prediction/medical_insurance.csv

# %%
dataset = pd.read_csv(filenames)

# %%
dataset.describe()
# Out:
#                age          bmi     children       charges
# count  2772.000000  2772.000000  2772.000000   2772.000000
# mean     39.109668    30.701349     1.101732  13261.369959
# std      14.081459     6.129449     1.214806  12151.768945
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.220000     0.000000   4687.797000
# 50%      39.000000    30.447500     1.000000   9333.014350
# 75%      51.000000    34.770000     2.000000  16577.779500
# max      64.000000    53.130000     5.000000  63770.428010

# %%
dataset["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# set southwest as 0, southeast as 1, northwest as 2 and northeaset as 3
dataset["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
# %%capture
dataset["region_en"] = 0
en_code = [0,1,2,3]
for uniq, code in zip(dataset["region"].unique(), en_code):
    dataset["region_en"][dataset.loc[:,"region"]== uniq] = code

# %%
# %%capture
dataset["sex_en"] = 0
code = [0,1]
for uniq,unicode in zip(dataset["sex"].unique(), code):
    dataset["sex_en"][dataset.loc[:,"sex"] == uniq] = unicode

# %%
new_dataset = dataset.loc[:,["age","bmi","children","sex_en","region_en","charges"]]

# %%
dset = np.array(new_dataset)
meanY = dset[:,-1].mean()
dset[:,-1] = dset[:,-1]/dset[:,-1].mean() 
training_size = int(0.9*new_dataset.shape[0])

# %%
train_rows = np.random.randint(0, dset.shape[0],training_size)
train_rows = np.unique(train_rows)
print(train_rows.shape[0])
# Out:
# 1654

# %%
total_rows = np.round(np.arange(0,dset.shape[0],1),0)
total_rows.shape
# Out:
# (2772,)

# %%
test_rows = np.array([ i for i in total_rows if i not in train_rows])
test_rows.shape[0] + train_rows.shape[0]
# Out:
# 2772

# %%
test_data = dset[test_rows]
train_data = dset[train_rows]

# %%
trainX,trainY = train_data[:,:-1], train_data[:,-1]
testX,testY = test_data[:,:-1], test_data[:,-1]
trainX = np.hstack((trainX,np.ones((trainX.shape[0],1))))
testX = np.hstack((testX,np.ones((testX.shape[0],1))))
trainY = trainY.reshape(trainY.shape[0],1)
testY = testY.reshape(testY.shape[0],1)

# %%
weight_size = trainX.shape[1]
weights = np.random.normal(0,1,(1,weight_size))

# %%
weights
# Out:
# array([[-2.30341095, -0.2027166 , -0.32740534,  0.33022106, -0.77801835,
#          0.85386395]])

# %%
Y = trainX@weights.T
MSE = (np.square(trainY - Y )).sum()/(2*Y.shape[0])
learning_rate = 0.01
intermediate = trainX*(trainX@weights.T - trainY)

# %%
# (trainX*(trainX@weights.T - trainY)).sum()
# weights

# %%
MSE = []
for i in range(1000):
    learning_rate = 0.001
    weights = weights  - learning_rate*((trainX@weights.T - trainY)*trainX).sum(axis = 0)/trainY.shape[0]
    losses = np.square(trainX@weights.T - trainY).sum()/(2*trainY.shape[0])
    MSE.append(losses)

# %%
MSE
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
np.hstack((np.array([1,2,3]),np.array([1])))
# Out:
# array([1, 2, 3, 1])
