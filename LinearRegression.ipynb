# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x= np.linspace(1,100,1000,endpoint=True)
y= np.linspace(100,10000,1000,endpoint=True)
z= np.linspace(-500,100,1000,endpoint=True)
Y = x + 100*y + 50*z   +25.5
X = np.array([x,y,z,np.ones(x.size)])

# %%
Y
# Out:
# (4, 1000)

# %%
w = np.random.normal(4,2,4)
alpha = 0.00000001 #Requires rescaling the data

# %%
def CostFunction(y_hat,y):
    return ((y_hat-y)**2).sum()/y.size*1/2

# %%
def dCdw(y_hat,Y,X,weight):
    return 1/y.size * ((y_hat-Y)@X.T).sum()

# %%
correction = []
for i in range(1000000):
    y_hat = w@X
    
    w = w - alpha * dCdw(y_hat,Y,X,w)

# %%
a = np.array([1,2,3])
b = np.array([10,12,14])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax= fig.add_subplot(111, projection="3d")
ax.scatter(x,y,Y)

# %%
# Out:
# array([99.89068527, 99.61192928, 95.57782573, 95.07901072])
